# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Read data

# %%
dataset_path = "IMDB-Movie-Data.csv"

# %%
data = pd.read_csv(dataset_path)

# %% [markdown]
# # 2. View data

# %%
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore
# 0     8.1  757074              333.13       76.0
# 1     7.0  485820              126.46       65.0
# 2     7.3  157606              138.12       62.0
# 3     7.2   60545              270.32       59.0
# 4     6.2  393727              325.02       40.0

# %% [markdown]
# # 3. Understand some basic information about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# max            936.630000  100.000000

# %% [markdown]
# # 4. Data Selection - Indexing and Slicing data

# %%
# Extract data as series
genre = data["Genre"]
genre
# Out:
# 0       Action,Adventure,Sci-Fi
# 1      Adventure,Mystery,Sci-Fi
# 2               Horror,Thriller
# 3       Animation,Comedy,Family
# 4      Action,Adventure,Fantasy
#                  ...
# 995         Crime,Drama,Mystery
# 996                      Horror
# 997         Drama,Music,Romance
# 998            Adventure,Comedy
# 999       Comedy,Family,Fantasy
# Name: Genre, Length: 1000, dtype: object

# %%
# Extract data as dataframe
genre = data[["Genre"]]
genre
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %%
some_cols = data[["Title", "Description", "Year", "Rating"]]
some_cols
# Out:
#                        Title  \
# 0    Guardians of the Galaxy
# 1                 Prometheus
# 2                      Split
# 3                       Sing
# 4              Suicide Squad
# ..                       ...
# 995     Secret in Their Eyes
# 996          Hostel: Part II
# 997   Step Up 2: The Streets
# 998             Search Party
# 999               Nine Lives
#
#                                            Description  Year  Rating
# 0    A group of intergalactic criminals are forced ...  2014     8.1
# 1    Following clues to the origin of mankind, a te...  2012     7.0
# 2    Three girls are kidnapped by a man with a diag...  2016     7.3
# 3    In a city of humanoid animals, a hustling thea...  2016     7.2
# 4    A secret government agency recruits some of th...  2016     6.2
# ..                                                 ...   ...     ...
# 995  A tight-knit team of rising investigators, alo...  2015     6.2
# 996  Three American college students studying abroa...  2007     5.5
# 997  Romantic sparks occur between two dance studen...  2008     6.2
# 998  A pair of friends embark on a mission to reuni...  2014     5.6
# 999  A stuffy businessman finds himself trapped ins...  2016     5.3
#
# [1000 rows x 4 columns]

# %%
data.iloc[30:40][["Title", "Genre", "Description"]]
# Out:
#                                Title                     Genre  \
# 30                          Why Him?                    Comedy
# 31                 Nocturnal Animals            Drama,Thriller
# 32                 X-Men: Apocalypse   Action,Adventure,Sci-Fi
# 33                          Deadpool   Action,Adventure,Comedy
# 34  Resident Evil: The Final Chapter      Action,Horror,Sci-Fi
# 35        Captain America: Civil War   Action,Adventure,Sci-Fi
# 36                      Interstellar    Adventure,Drama,Sci-Fi
# 37                    Doctor Strange  Action,Adventure,Fantasy
# 38             The Magnificent Seven  Action,Adventure,Western
# 39                         5- 25- 77              Comedy,Drama
#
#                                           Description
# 30  A holiday gathering threatens to go off the ra...
# 31  A wealthy art gallery owner is haunted by her ...
# 32  After the re-emergence of the world's first mu...
# 33  A fast-talking mercenary with a morbid sense o...
# 34  Alice returns to where the nightmare began: Th...
# 35  Political interference in the Avengers' activi...
# 36  A team of explorers travel through a wormhole ...
# 37  While on a journey of physical and spiritual h...
# 38  Seven gunmen in the old west gradually come to...
# 39  Alienated, hopeful-filmmaker Pat Johnson's epi...

# %% [markdown]
# # 5. Data Selection - Based on Conditional filtering

# %%
data[(data["Year"] >= 2011) & (data["Year"] <= 2013) & (data["Rating"] >= 7.0) & (data["Revenue (Millions)"] >= data["Revenue (Millions)"].quantile(0.9))]
# Out:
#      Rank                                         Title  \
# 76     77                                  The Avengers
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 124   125                         The Dark Knight Rises
# 134   135                                     Furious 6
# 151   152                              The Hunger Games
# 174   175                                        Frozen
# 270   271                                       Skyfall
# 271   272             The Hobbit: An Unexpected Journey
# 279   280                                Iron Man Three
# 294   295                                  Man of Steel
# 319   320                                     Fast Five
# 362   363                       Star Trek Into Darkness
# 368   369                        The Amazing Spider-Man
# 412   413                           Monsters University
# 509   510                                       Gravity
# 518   519           The Hobbit: The Desolation of Smaug
# 578   579               The Hunger Games: Catching Fire
# 589   590                                         Brave
# 701   702                                           Ted
# 797   798                               Despicable Me 2
#
#                           Genre  \
# 76                Action,Sci-Fi
# 114     Adventure,Drama,Fantasy
# 124             Action,Thriller
# 134       Action,Crime,Thriller
# 151   Adventure,Sci-Fi,Thriller
# 174  Animation,Adventure,Comedy
# 270   Action,Adventure,Thriller
# 271           Adventure,Fantasy
# 279     Action,Adventure,Sci-Fi
# 294    Action,Adventure,Fantasy
# 319       Action,Crime,Thriller
# 362     Action,Adventure,Sci-Fi
# 368            Action,Adventure
# 412  Animation,Adventure,Comedy
# 509       Drama,Sci-Fi,Thriller
# 518           Adventure,Fantasy
# 578    Action,Adventure,Mystery
# 589  Animation,Adventure,Comedy
# 701              Comedy,Fantasy
# 797  Animation,Adventure,Comedy
#
#                                            Description           Director  \
# 76   Earth's mightiest heroes must come together an...        Joss Whedon
# 114  Harry, Ron and Hermione search for Voldemort's...        David Yates
# 124  Eight years after the Joker's reign of anarchy...  Christopher Nolan
# 134  Hobbs has Dominic and Brian reassemble their c...         Justin Lin
# 151  Katniss Everdeen voluntarily takes her younger...          Gary Ross
# 174  When the newly crowned Queen Elsa accidentally...         Chris Buck
# 270  Bond's loyalty to M is tested when her past co...         Sam Mendes
# 271  A reluctant hobbit, Bilbo Baggins, sets out to...      Peter Jackson
# 279  When Tony Stark's world is torn apart by a for...        Shane Black
# 294  Clark Kent, one of the last of an extinguished...        Zack Snyder
# 319  Dominic Toretto and his crew of street racers ...         Justin Lin
# 362  After the crew of the Enterprise find an unsto...        J.J. Abrams
# 368  After Peter Parker is bitten by a genetically ...          Marc Webb
# 412  A look at the relationship between Mike and Su...        Dan Scanlon
# 509  Two astronauts work together to survive after ...     Alfonso Cuarón
# 518  The dwarves, along with Bilbo Baggins and Gand...      Peter Jackson
# 578  Katniss Everdeen and Peeta Mellark become targ...   Francis Lawrence
# 589  Determined to make her own path in life, Princ...       Mark Andrews
# 701  John Bennett, a man whose childhood wish of br...    Seth MacFarlane
# 797  When Gru, the world's most super-bad turned su...      Pierre Coffin
#
#                                                 Actors  Year  \
# 76   Robert Downey Jr., Chris Evans, Scarlett Johan...  2012
# 114  Daniel Radcliffe, Emma Watson, Rupert Grint, M...  2011
# 124  Christian Bale, Tom Hardy, Anne Hathaway,Gary ...  2012
# 134  Vin Diesel, Paul Walker, Dwayne Johnson, Miche...  2013
# 151  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...  2012
# 174  Kristen Bell, Idina Menzel, Jonathan Groff, Jo...  2013
# 270  Daniel Craig, Javier Bardem, Naomie Harris, Ju...  2012
# 271  Martin Freeman, Ian McKellen, Richard Armitage...  2012
# 279  Robert Downey Jr., Guy Pearce, Gwyneth Paltrow...  2013
# 294  Henry Cavill, Amy Adams, Michael Shannon, Dian...  2013
# 319  Vin Diesel, Paul Walker, Dwayne Johnson, Jorda...  2011
# 362  Chris Pine, Zachary Quinto, Zoe Saldana, Bened...  2013
# 368  Andrew Garfield, Emma Stone, Rhys Ifans, Irrfa...  2012
# 412  Billy Crystal, John Goodman, Steve Buscemi, He...  2013
# 509  Sandra Bullock, George Clooney, Ed Harris, Ort...  2013
# 518  Ian McKellen, Martin Freeman, Richard Armitage...  2013
# 578  Jennifer Lawrence, Josh Hutcherson, Liam Hemsw...  2013
# 589  Kelly Macdonald,Billy Connolly, Emma Thompson,...  2012
# 701  Mark Wahlberg, Mila Kunis, Seth MacFarlane, Jo...  2012
# 797  Steve Carell, Kristen Wiig, Benjamin Bratt, Mi...  2013
#
#      Runtime (Minutes)  Rating    Votes  Revenue (Millions)  Metascore
# 76                 143     8.1  1045588              623.28       69.0
# 114                130     8.1   590595              380.96       87.0
# 124                164     8.5  1222645              448.13       78.0
# 134                130     7.1   318051              238.67       61.0
# 151                142     7.2   735604              408.00       68.0
# 174                102     7.5   451894              400.74       74.0
# 270                143     7.8   547386              304.36       81.0
# 271                169     7.9   668651              303.00       58.0
# 279                130     7.2   591023              408.99       62.0
# 294                143     7.1   577010              291.02       55.0
# 319                131     7.3   300803              209.81       66.0
# 362                132     7.8   417663              228.76       72.0
# 368                136     7.0   474320              262.03       66.0
# 412                104     7.3   252119              268.49       65.0
# 509                 91     7.8   622089              274.08       96.0
# 518                161     7.9   513744              258.36       66.0
# 578                146     7.6   525646              424.65       76.0
# 589                 93     7.2   293941              237.28       69.0
# 701                106     7.0   494641              218.63       62.0
# 797                 98     7.4   304837              368.05       62.0

# %% [markdown]
# # 6. Groupby Operations

# %%
data.groupby("Director")[["Rating"]].mean().sort_values(by="Rating", ascending=False)
# Out:
#                    Rating
# Director
# Nitesh Tiwari        8.80
# Christopher Nolan    8.68
# Olivier Nakache      8.60
# Makoto Shinkai       8.60
# Aamir Khan           8.50
# ...                   ...
# Micheal Bafaro       3.50
# Jonathan Holbrook    3.20
# Shawn Burkett        2.70
# James Wong           2.70
# Jason Friedberg      1.90
#
# [644 rows x 1 columns]

# %% [markdown]
# # 7. Sorting Operations

# %%
data.groupby("Director")[["Rating", "Metascore"]].mean().sort_values(["Rating", "Metascore"], ascending=False).head(10)
# Out:
#                                   Rating  Metascore
# Director
# Nitesh Tiwari                       8.80        NaN
# Christopher Nolan                   8.68       74.8
# Makoto Shinkai                      8.60       79.0
# Olivier Nakache                     8.60       57.0
# Florian Henckel von Donnersmarck    8.50       89.0
# Aamir Khan                          8.50       42.0
# Damien Chazelle                     8.40       90.5
# Naoko Yamada                        8.40       80.0
# Lee Unkrich                         8.30       92.0
# Thomas Vinterberg                   8.30       76.0

# %% [markdown]
# # 8. View missing values

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # 9. Deal with missing values - Deleting

# %%
data.drop("Metascore", axis=1).head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)
# 0     8.1  757074              333.13
# 1     7.0  485820              126.46
# 2     7.3  157606              138.12
# 3     7.2   60545              270.32
# 4     6.2  393727              325.02

# %%
data.dropna()
# Out:
#      Rank                     Title                     Genre  \
# 0       1   Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2                Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                     Split           Horror,Thriller
# 3       4                      Sing   Animation,Comedy,Family
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# ..    ...                       ...                       ...
# 993   994  Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                 Project X                    Comedy
# 996   997           Hostel: Part II                    Horror
# 997   998    Step Up 2: The Streets       Drama,Music,Romance
# 999  1000                Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# 1    Following clues to the origin of mankind, a te...          Ridley Scott
# 2    Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3    In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4    A secret government agency recruits some of th...            David Ayer
# ..                                                 ...                   ...
# 993  While still out to destroy the evil Umbrella C...    Paul W.S. Anderson
# 994  3 high school seniors throw a birthday party t...       Nima Nourizadeh
# 996  Three American college students studying abroa...              Eli Roth
# 997  Romantic sparks occur between two dance studen...            Jon M. Chu
# 999  A stuffy businessman finds himself trapped ins...      Barry Sonnenfeld
#
#                                                 Actors  Year  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016
# 3    Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016
# 4    Will Smith, Jared Leto, Margot Robbie, Viola D...  2016
# ..                                                 ...   ...
# 993  Milla Jovovich, Ali Larter, Wentworth Miller,K...  2010
# 994  Thomas Mann, Oliver Cooper, Jonathan Daniel Br...  2012
# 996  Lauren German, Heather Matarazzo, Bijou Philli...  2007
# 997  Robert Hoffman, Briana Evigan, Cassie Ventura,...  2008
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016
#
#      Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 0                  121     8.1  757074              333.13       76.0
# 1                  124     7.0  485820              126.46       65.0
# 2                  117     7.3  157606              138.12       62.0
# 3                  108     7.2   60545              270.32       59.0
# 4                  123     6.2  393727              325.02       40.0
# ..                 ...     ...     ...                 ...        ...
# 993                 97     5.9  140900               60.13       37.0
# 994                 88     6.7  164088               54.72       48.0
# 996                 94     5.5   73152               17.54       46.0
# 997                 98     6.2   70699               58.01       50.0
# 999                 87     5.3   12435               19.64       11.0
#
# [838 rows x 12 columns]

# %% [markdown]
# # 10. Dealing with missing values - Filling

# %%
revenue_mean = data["Revenue (Millions)"].mean()
print("The mean revenue is:", revenue_mean)
metascore_median = data["Metascore"].median()
print("The median metascore is:", metascore_median)

data["Revenue (Millions)"].fillna(revenue_mean, inplace=True)
data["Metascore"].fillna(metascore_median, inplace=True)
data.isnull().sum()
# Out:
# The mean revenue is: 82.95637614678898
# The median metascore is: 59.5
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# # 11. apply() function

# %%
def rating_group(rating):
  if rating >= 7.5:
    return "Good"
  elif rating >= 6.0:
    return "Average"
  else:
    return "Bad"

data["Rating_category"] = data["Rating"].apply(rating_group)
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# 0  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014                121
# 1  Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012                124
# 2  James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016                117
# 3  Matthew McConaughey,Reese Witherspoon, Seth Ma...  2016                108
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  2016                123
#
#    Rating   Votes  Revenue (Millions)  Metascore Rating_category
# 0     8.1  757074              333.13       76.0            Good
# 1     7.0  485820              126.46       65.0         Average
# 2     7.3  157606              138.12       62.0         Average
# 3     7.2   60545              270.32       59.0         Average
# 4     6.2  393727              325.02       40.0         Average

# %%
def review_director(metascore_of_director):
  if metascore_of_director >= 90:
    return "Excellent"
  elif metascore_of_director >= 70:
    return "Good"
  elif metascore_of_director >= 50:
    return "Average"
  else:
    return "Bad"

data_director = data.groupby("Director")[["Metascore"]].mean()
data_director["Director_category"] = data_director["Metascore"].apply(review_director)
data_director
# Out:
#                      Metascore Director_category
# Director
# Aamir Khan                42.0               Bad
# Abdellatif Kechiche       88.0              Good
# Adam Leon                 77.0              Good
# Adam McKay                65.5           Average
# Adam Shankman             64.0           Average
# ...                        ...               ...
# Xavier Dolan              61.0           Average
# Yimou Zhang               42.0               Bad
# Yorgos Lanthimos          77.5              Good
# Zack Snyder               48.0               Bad
# Zackary Adler             90.0         Excellent
#
# [644 rows x 2 columns]
